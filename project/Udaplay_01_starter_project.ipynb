# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 01 - Offline RAG
#
# In this part of the project, you'll build your VectorDB using Chroma.
#
# The data is inside folder `project/starter/games`. Each file will become a document in the collection you'll create.
# Example.:
# ```json
# {
#   "Name": "Gran Turismo",
#   "Platform": "PlayStation 1",
#   "Genre": "Racing",
#   "Publisher": "Sony Computer Entertainment",
#   "Description": "A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.",
#   "YearOfRelease": 1997
# }
# ```

# %% [markdown]
# ### Setup

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
import json
import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### VectorDB Instance

# %%
chroma_client = chromadb.PersistentClient(path="chromadb")

# %% [markdown]
# ### Collection

# %%
embedding_fn = embedding_functions.OpenAIEmbeddingFunction(
    model_name="text-embedding-3-small"
)

# %%
collection = chroma_client.create_collection(
   name="udaplay",
   embedding_function=embedding_fn
)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 collection = chroma_client.create_collection(
#       2    name="udaplay",
#       3    embedding_function=embedding_fn
#       4 )
#
# File ~/Bootcamps/udaplay/.venv/lib/python3.13/site-packages/chromadb/api/client.py:183, in Client.create_collection(self, name, schema, configuration, metadata, embedding_function, data_loader, get_or_create)
#     180 if embedding_function is not None and configuration_ef is None:
#     181     configuration["embedding_function"] = embedding_function
# --> 183 model = self._server.create_collection(
#     184     name=name,
#     185     schema=schema,
#     186     metadata=metadata,
#     187     tenant=self.tenant,
#     188     database=self.database,
#     189     get_or_create=get_or_create,
#     190     configuration=configuration,
#     191 )
#     192 return Collection(
#     193     client=self._server,
#     194     model=model,
#     195     embedding_function=embedding_function,
#     196     data_loader=data_loader,
#     197 )
#
# File ~/Bootcamps/udaplay/.venv/lib/python3.13/site-packages/chromadb/api/rust.py:242, in RustBindingsAPI.create_collection(self, name, schema, configuration, metadata, get_or_create, tenant, database)
#     239 else:
#     240     schema_str = None
# --> 242 collection = self.bindings.create_collection(
#     243     name,
#     244     configuration_json_str,
#     245     schema_str,
#     246     metadata,
#     247     get_or_create,
#     248     tenant,
#     249     database,
#     250 )
#     251 collection_model = CollectionModel(
#     252     id=collection.id,
#     253     name=collection.name,
#    (...)    259     database=collection.database,
#     260 )
#     261 return collection_model
#
# InternalError: Collection [udaplay] already exists

# %% [markdown]
# ### Add documents

# %%
# Make sure you have a directory "project/starter/games"
data_dir = "games"

for file_name in sorted(os.listdir(data_dir)):
    if not file_name.endswith(".json"):
        continue

    file_path = os.path.join(data_dir, file_name)
    with open(file_path, "r", encoding="utf-8") as f:
        game = json.load(f)

    # You can change what text you want to index
    content = f"[{game['Platform']}] {game['Name']} ({game['YearOfRelease']}) - {game['Description']}"

    # Use file name (like 001) as ID
    doc_id = os.path.splitext(file_name)[0]

    collection.add(
        ids=[doc_id],
        documents=[content],
        metadatas=[game]
    )
